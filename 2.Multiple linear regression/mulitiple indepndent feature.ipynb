# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('Ice Cream.csv')

# %%
df.head()
# Out:
#    Temperature_C  Humidity_%  Weekend  Holiday  Promotion  Footfall  \
# 0             22          65        0        0          0       120
# 1             24          60        0        0          1       150
# 2             26          58        1        0          1       220
# 3             28          55        1        0          0       200
# 4             30          50        0        0          1       260
#
#    IceCream_Sales
# 0             210
# 1             280
# 2             410
# 3             360
# 4             480

# %%
df.shape
# Out:
# (54, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Temperature_C   54 non-null     int64
#  1   Humidity_%      54 non-null     int64
#  2   Weekend         54 non-null     int64
#  3   Holiday         54 non-null     int64
#  4   Promotion       54 non-null     int64
#  5   Footfall        54 non-null     int64
#  6   IceCream_Sales  54 non-null     int64
# dtypes: int64(7)
# memory usage: 3.1 KB

# %%
df.isnull().sum()
# Out:
# Temperature_C     0
# Humidity_%        0
# Weekend           0
# Holiday           0
# Promotion         0
# Footfall          0
# IceCream_Sales    0
# dtype: int64

# %%
sns.pairplot(df)

# %%
df.corr()
# Out:
#                 Temperature_C  Humidity_%       Weekend   Holiday  \
# Temperature_C        1.000000   -0.971171  4.769723e-01  0.639925
# Humidity_%          -0.971171    1.000000 -4.326615e-01 -0.601457
# Weekend              0.476972   -0.432662  1.000000e+00  0.447214
# Holiday              0.639925   -0.601457  4.472136e-01  1.000000
# Promotion            0.404724   -0.381501  1.744547e-17  0.316228
# Footfall             0.961456   -0.918211  5.266295e-01  0.688581
# IceCream_Sales       0.951031   -0.907076  5.221963e-01  0.745141
#
#                    Promotion  Footfall  IceCream_Sales
# Temperature_C   4.047244e-01  0.961456        0.951031
# Humidity_%     -3.815009e-01 -0.918211       -0.907076
# Weekend         1.744547e-17  0.526630        0.522196
# Holiday         3.162278e-01  0.688581        0.745141
# Promotion       1.000000e+00  0.541592        0.566344
# Footfall        5.415923e-01  1.000000        0.995583
# ...

# %%
plt.scatter(df['Temperature_C'],df['Weekend'],df['Holiday'],df['Promotion'],
            df['Footfall'],)
# Out:
# C:\Users\belan\AppData\Local\Temp\ipykernel_2312\2440839324.py:1: MatplotlibDeprecationWarning: Passing the marker parameter of scatter() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.scatter(df['Temperature_C'],df['Weekend'],df['Holiday'],df['Promotion'],
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File f:\anaconda\Lib\site-packages\matplotlib\markers.py:326, in MarkerStyle._set_marker(self, marker)
#     325 try:
# --> 326     Path(marker)
#     327     self._marker_function = self._set_vertices
#
# File f:\anaconda\Lib\site-packages\matplotlib\path.py:130, in Path.__init__(self, vertices, codes, _interpolation_steps, closed, readonly)
#     129 vertices = _to_unmasked_float_array(vertices)
# --> 130 _api.check_shape((None, 2), vertices=vertices)
#     132 if codes is not None and len(vertices):
#
# ...
